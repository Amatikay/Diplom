# %% [markdown]
# ![image](../pic/pic1.jpg)
# ![image](../pic/pic2.jpg)

# %% [markdown]
# Длинные названия потому, что за жизненным циклом обектов следить не умею :)

# %% [markdown]
# Симулирую **ТОЛЬКО** создание новых связей

# %%
Generate_Network_t0 <- function(size = 40, sparsity = 0.7) {
	network <- matrix(0, nrow=size, ncol=size)
  
	for (i in 1:size) {
		for (j in 1:size) {
			if (runif(1) > sparsity) {
				network[i, j] <- 1
			}
		}
	}
  
	return(network)
}


Network_function_1 <- function(i, Network) { # outdegree (density)
	net <- sum(Network[i, ])
	return(net)
}


Network_function_2 <- function(i, Network) { # recip
	net <- 0
    for(j in 1:length(Network[1,])){
        if(i != j){
            net <- net + Network[i,j]*Network[j,i]
        }
    }
	return(net)
}

Network_function_3 <- function(i, Network) { # transitive triads (transTrip)
	net <- 0
	for (j in 1:length(Network[i, ])) {
		for(h in 1:length(Network[i, ])){
			if(i!=j & j!=h & i!=h){
				net <- net + (Network[i,j] * Network[i,h] * Network[h,j]) 
			}
		}
	}
	return(net)
}

Generate_Possible_Ministep_Matrix_vector <- function(i, Network) {
	Networks <- list()
  
	for (j in 1:length(Network[i, ])) {
		if (i != j) {
			TMP_Net <- Network
			TMP_Net[i, j] <- 1
			Networks[[j]] <- TMP_Net    
		}
	}
	return(Networks)
}

Ministep <- function(Network, i, j) {
	Network[i, j] <- 1
	return(Network)
}


Distribution_actors <- function(i, Network, beta) {
	Util <- numeric( length(Network[i, ]) )
	total_util <- 0
  
	for (h in 1:length(Network[i, ])) {
		if (i != h) {
			total_util <- total_util + exp(Utility(Network, beta, i, h))
		}
	}
  
	Util_j <- numeric(length(Network[i, ]))
  
	for (j in 1:length(Network[i, ])) {
		if (j != i) {
			Util_j[j] <- exp(Utility(Network, beta, i, j))
            # print(Util_j[j])
            # print(total_util)
			Util[j] <- Util_j[j] / total_util
		}
	}
    print(i)
    print(Util) # На всех шагах всегда матирциа полезности одинкова для всех акторах. Странно
	# На сетях 1 и 2 матрица полезностей так же идентична
    Util[which(is.na(Util))] <- 0
	return(Util)
}

Utility <- function(Network, beta, i, j) {
	util <- 0
	util <- util + (beta[1] * Network_function_2(i, Network)) + (beta[2] * Network_function_3(i, Network))
	return(util)
}

Simulator <- function(Network0, t = 0, LambdaV, total_Lambda, T, beta) {
	Network <- Network0 
	while (t < T) {
		deltaT <- rexp(1, rate=total_Lambda)
		i <- sample(1:length(Network0[1, ]), size=1, prob=(LambdaV / total_Lambda))
      
		prob_vector <- 0
		prob_vector <- Distribution_actors(i, Network, beta)
        # print(sum(prob_vector))
		j <- sample(1:length(Network0[i,]), size=1, prob=prob_vector)
		Network[i, j] <- 1
		t <- t + deltaT

	}
	return(Network)
}

# %%
size <- 30
Network0 <- Generate_Network_t0(size = size)
LambdaV <- runif(n = size, min = 0, max = 1) 
total_Lambda <- sum(LambdaV)
# total_Lambda
beta <- runif(n = 2, min = 0, max = 1)
# beta <- c(.3,.6)
T <- 3
# total_Lambda

# %% [raw]
# # Блок отладки
# for(k in 1:size){
#     print("Итерация")
#     print(k)
#     print("Распределение")
#     print(Distribution_actors(k, Network0, beta))
#     print("Сумма")
#     print(sum(Distribution_actors(k, Network0, beta)))
#     print("Функция  сети 1")
#     print(Network_function_1(k,Network0))
#     print("Функция  сети 3")
#     print(Network_function_3(k,Network0))
# }

# %% [raw]
# write.table(Network0, file = "Network0.dat", sep = " ", row.names = FALSE, col.names = FALSE)

# %%
Network1 <- Simulator(Network0, t = 0, LambdaV, total_Lambda, T, beta)
# Out:
# [1] 27
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276 0.03448276
# [1] 13
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.00000000 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 22
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 22
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 9
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 4
#  [1] 0.03448276 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 22
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 21
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 18
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.00000000
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 1
#  [1] 0.00000000 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 21
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 24
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.00000000
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 24
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.00000000
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 20
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.00000000 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 24
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.00000000
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 26
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.00000000 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 22
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 15
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 3
#  [1] 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 30
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.00000000
# [1] 24
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.00000000
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 15
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 30
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.00000000
# [1] 28
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276
# [1] 30
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.00000000
# [1] 30
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.00000000
# [1] 16
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 30
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.00000000
# [1] 26
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.00000000 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 28
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276
# [1] 10
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 27
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276 0.03448276
# [1] 10
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 28
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276
# [1] 21
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 26
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.00000000 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 26
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.00000000 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 17
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.00000000 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276

# %% [raw]
# write.table(Network1, file = "Network1.dat", sep = " ", row.names = FALSE, col.names = FALSE)

# %%
Network2 <- Simulator(Network1, t = 0, LambdaV, total_Lambda, T, beta)
# Out:
# [1] 13
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.00000000 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 21
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 1
#  [1] 0.00000000 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 13
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.00000000 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 18
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.00000000
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 15
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 14
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.00000000 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 8
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.00000000 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 15
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 13
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.00000000 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 10
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 28
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276
# [1] 25
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.00000000 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 18
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.00000000
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 11
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.00000000 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 9
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 17
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.00000000 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 18
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.00000000
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 27
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276 0.03448276
# [1] 11
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.00000000 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 27
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276 0.03448276
# [1] 30
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.00000000
# [1] 8
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.00000000 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 26
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.00000000 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 17
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.00000000 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 4
#  [1] 0.03448276 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 25
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.00000000 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 14
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.00000000 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 25
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.00000000 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 22
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 27
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276 0.03448276
# [1] 19
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.00000000 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 8
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.00000000 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 1
#  [1] 0.00000000 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 13
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.00000000 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 22
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 3
#  [1] 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 3
#  [1] 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 26
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.00000000 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 13
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.00000000 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 4
#  [1] 0.03448276 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 27
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276 0.03448276
# [1] 9
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 21
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 7
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.00000000 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 16
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 6
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.00000000
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 16
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 10
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 1
#  [1] 0.00000000 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 13
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.00000000 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 21
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.00000000 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 25
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.00000000 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 24
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.00000000
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 1
#  [1] 0.00000000 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [1] 23
#  [1] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  [7] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [13] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
# [19] 0.03448276 0.03448276 0.03448276 0.03448276 0.00000000 0.03448276
# [25] 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276

# %% [raw]
# write.table(Network2, file = "Network2.dat", sep = " ", row.names = FALSE, col.names = FALSE)

# %%
sum(Network0)
sum(Network1)
sum(Network2)
# Out:
# [1] 290
# [1] 317
# [1] 352

# %% [markdown]
# ---
# # Проверка в RSiena

# %%
library(RSiena)

# %%
Networks <- array(c(Network0, Network1, Network2), dim = c(size, size, 3))

Networks <- sienaDependent(Networks, nodeSet="Actors")

Networks
# Out:
# Type         oneMode
# Observations 3
# Nodeset      Actors (30 elements)

# %%
mydata <- sienaDataCreate(Networks)
myeff <- getEffects(mydata)
mydata
# Out:
# For dependent variable Networks, in some periods,
#
# there are only increases, or only decreases.
#
# This will be respected in the simulations.
#
# If this is not desired, use allowOnly=FALSE when creating the dependent variable.
# Dependent variables:  Networks
# Number of observations: 3
#
# Nodeset                  Actors
# Number of nodes              30
#
# Dependent variable Networks
# Type               oneMode
# Observations       3
# Nodeset            Actors
# Densities          0.32 0.35 0.39
#
# "uponly":  Networks:    all periods

# %% [markdown]
# Сиена видит коэффиценты разреженности. Они идентичны заданным.
#
# Так же в предупреждении указано, что сеть только увеличивалась или уменьшалась, что корректно отвечает заданным условиям.

# %%
effectsDocumentation(myeff,type = "html", display = FALSE)
# Out:
# Effects documentation written to file myeff.html .

# %%
myeff <- includeEffects(myeff, recip  , type = "creation", include = TRUE)
myeff <- includeEffects(myeff, recip  , type = "eval", include = FALSE)
myeff <- includeEffects(myeff, transTrip, type = "creation", include = TRUE)
# myeff <- includeEffects(myeff, transTrip, include = TRUE)
# Out:
#   effectName  include fix   test  initialValue parm type
# 1 reciprocity TRUE    FALSE FALSE          0   0    creation
# [1] effectName   include      fix          test         initialValue
# [6] parm
# <0 rows> (or 0-length row.names)
#   effectName          include fix   test  initialValue parm type
# 1 transitive triplets TRUE    FALSE FALSE          0   0    creation

# %%
summary(myeff)
# Out:
#                         name     effectName
# Networks.rate.1         Networks constant Networks rate (period 1)
# Networks.rate.2         Networks constant Networks rate (period 2)
# Networks.obj.creation.1 Networks reciprocity
# Networks.obj.creation.2 Networks transitive triplets
#                         functionName                            shortName
# Networks.rate.1         Amount of network change in period 1    Rate
# Networks.rate.2         Amount of network change in period 2    Rate
# Networks.obj.creation.1 New ties: Number of reciprocated ties   recip
# Networks.obj.creation.2 New ties: Number of transitive triplets transTrip
#                         interaction1 interaction2 type     basicRate include
# Networks.rate.1                                   rate      TRUE     TRUE
# Networks.rate.2                                   rate      TRUE     TRUE
# Networks.obj.creation.1                           creation FALSE     TRUE
# Networks.obj.creation.2                           creation FALSE     TRUE
#                         randomEffects ⋯ effect3 interactionType local setting
# Networks.rate.1         FALSE         ⋯ 0                       TRUE
# Networks.rate.2         FALSE         ⋯ 0                       TRUE
# Networks.obj.creation.1 FALSE         ⋯ 0       dyadic          TRUE
# Networks.obj.creation.2 FALSE         ⋯ 0                       TRUE
#                         effectFn statisticFn netType groupName group
# Networks.rate.1         NULL     NULL        oneMode Group1    1
# Networks.rate.2         NULL     NULL        oneMode Group1    1
# Networks.obj.creation.1 NULL     NULL        oneMode Group1    1
# Networks.obj.creation.2 NULL     NULL        oneMode Group1    1
#                         effectNumber
# Networks.rate.1          1
# Networks.rate.2          2
# Networks.obj.creation.1 14
# Networks.obj.creation.2 20

# %%
myalgorithm <- sienaAlgorithmCreate(projname = 'Тест симулятора сети')
ans <- siena07( myalgorithm, data = mydata,silent = TRUE ,effects = myeff,batch = TRUE, clusterType="FORK", useCluster=TRUE, nbrNodes=12)
# Out:
# If you use this algorithm object, siena07 will create/use an output file Тест симулятора сети.txt .

# %%
ans
# Out:
# Estimates, standard errors and convergence t-ratios
#
#                                     Estimate   Standard   Convergence
#                                                  Error      t-ratio
#
# Rate parameters:
#   0.1       Rate parameter period 1  0.9818  ( 0.1922   )
#   0.2       Rate parameter period 2  1.3114  ( 0.2243   )
#
# Other parameters:
#   1.  creat reciprocity              0.0887  ( 0.2977   )   -0.0628
#   2.  creat transitive triplets     -0.0981  ( 0.0992   )    0.0009
#
# Overall maximum convergence ratio:    0.0629
#
#
# Total of 1643 iteration steps.

# %% [markdown]
# Необходимо помнить, что оцениваем $ exp(\text{парамтер}) $ (Для созданных мной параметров)

# %% [markdown]
# ---
# Скриптом `../data/main.r` запустил 40 повторов. Графики сходимости (сходимости ли ?).
# В скрипт немного отличается от Ноубтбука. Правки вроде случайных начальных парметров
#
# beta - мои параметры.
# - beta1 - density
# - beta2 - transTrip
#
# teta - оцененые параметры
#
# rate - оцененая скорость
# - rate1 - 1 период
# - rate2 - 2 период
#
# totalLambda - суммарная интенсивность всех акторов (задана)

# %%
beta <- read.table("../data/beta.txt", sep = " ")
rate <- read.table("../data/rate.txt", sep = " ")
teta <- read.table("../data/teta.txt", sep = " ") # Почему то записывается только первый столбец, 
                                                  # но если запустить в jupyter 
                                                  # То выводятся оба
total_Lambda <- read.table("../data/totalLambda.txt", sep = " ")

# %%
log_total_lambda <- log((total_Lambda$V1[1]))

min_y <- min(min(rate$V1), min(rate$V2), log_total_lambda) - .4
max_y <- max(max(rate$V1), max(rate$V2), log_total_lambda)

plot(rate$V1, type = "l", col = "blue", ylim = c(min_y, max_y), 
     xlab = "Итерация", ylab = "Интенсивность", main = "Оцененная и теоретическая интенсивность")

lines(rate$V2, type = "l", col = "green")
abline(h = log_total_lambda, col = "red", lty = 2)

legend("bottomright", legend = c("Оцененная на 1 периоде", "Оцененная на 2 периоде", "Теоретическая на всех периодах"),
       col = c("blue", "green", "red"), lty = c(1, 1, 2), x.intersp = .3)
# Out:
# Plot with title “Оцененная и теоретическая интенсивность”

# %%
# Верно ли интерпертирую эффекты?

log(beta$V1[1])
sqrt(beta$V2[1])

plot(teta$V1, type="l", col="blue", ylim=c(-4, 1), main = "Параметры при эффектах", xlab = "Итерация", ylab = "Значение парамтера",)
abline(h = log(beta$V1[1]), col = "blue", lty = 2)
abline(h = sqrt(beta$V2[1]),col = "green", lty = 2)
lines(teta$V2, col = "green")

legend("bottomright", legend = c("Оцененый параметр", "Теоретическое значение"),
       col = c("blue", "red"), lty = c(1, 1), x.intersp = .3)
# Out:
# [1] -0.3796322
# [1] 0.6435247
# Plot with title “Параметры при эффектах”

# %%
mean(teta$V1)
mean(teta$V2)
# Out:
# [1] 0.01132398
# [1] 0.003804339

# %%
plot(density(teta$V1))
plot(density(teta$V2))
# Out:
# Plot with title “density(x = teta$V1)”
# Plot with title “density(x = teta$V2)”
